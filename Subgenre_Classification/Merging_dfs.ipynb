# %%
# %matplotlib inline

import os
import IPython.display as ipd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#import ast
#Built-in module from FMA
import utils

# %%
filepath='C:\\Users\\ramir\\OneDrive\\Documents\\GitHub\\fma_metadata\\tracks_clean.csv'
tracks = pd.read_csv(filepath, index_col = 'track_id')
tracks.head()
# Out:
#           year_released                 album album_id artist_id      artist  \
# track_id
# 2                2009.0  AWOL - A Way Of Life        1         1        AWOL
# 3                2009.0  AWOL - A Way Of Life        1         1        AWOL
# 5                2009.0  AWOL - A Way Of Life        1         1        AWOL
# 10               2008.0     Constant Hitmaker        6         6   Kurt Vile
# 20               2009.0                 Niris        4         4  Nicky Cook
#
#          genres_top         genres_all            track  duration
# track_id
# 2           Hip-Hop               [21]             Food     168.0
# 3           Hip-Hop               [21]     Electric Ave     237.0
# 5           Hip-Hop               [21]       This World     206.0
# 10              Pop               [10]          Freeway     161.0
# 20          UNKNOWN  [17, 10, 76, 103]  Spiritual Level     311.0

# %%
tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 106313 entries, 2 to 155320
# Data columns (total 9 columns):
# year_released    106313 non-null float64
# album            105273 non-null object
# album_id         106313 non-null object
# artist_id        106270 non-null object
# artist           106313 non-null object
# genres_top       106313 non-null object
# genres_all       106313 non-null object
# track            106017 non-null object
# duration         106313 non-null float64
# dtypes: float64(2), object(7)
# memory usage: 8.1+ MB

# %%
tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 106313 entries, 2 to 155320
# Data columns (total 9 columns):
# year_released    106313 non-null float64
# album            105273 non-null object
# album_id         106313 non-null object
# artist_id        106270 non-null object
# artist           106313 non-null object
# genres_top       106313 non-null object
# genres_all       106313 non-null object
# track            106017 non-null object
# duration         106313 non-null float64
# dtypes: float64(2), object(7)
# memory usage: 8.1+ MB

# %%
filepath='C:\\Users\\ramir\\OneDrive\\Documents\\GitHub\\fma_metadata\\echonest_audio_features.csv'
audio_features = pd.read_csv(filepath, index_col='track_id')

audio_features.head()
# Out:
#           acousticness  danceability    energy  instrumentalness  liveness  \
# track_id
# 2             0.416675      0.675894  0.634476          0.010628  0.177647
# 3             0.374408      0.528643  0.817461          0.001851  0.105880
# 5             0.043567      0.745566  0.701470          0.000697  0.373143
# 10            0.951670      0.658179  0.924525          0.965427  0.115474
# 134           0.452217      0.513238  0.560410          0.019443  0.096567
#
#           speechiness    tempo   valence
# track_id
# 2            0.159310  165.922  0.576661
# 3            0.461818  126.957  0.269240
# 5            0.124595  100.260  0.621661
# 10           0.032985  111.562  0.963590
# 134          0.525519  114.290  0.894072

# %%
audio_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13129 entries, 2 to 124911
# Data columns (total 8 columns):
# acousticness        13129 non-null float64
# danceability        13129 non-null float64
# energy              13129 non-null float64
# instrumentalness    13129 non-null float64
# liveness            13129 non-null float64
# speechiness         13129 non-null float64
# tempo               13129 non-null float64
# valence             13129 non-null float64
# dtypes: float64(8)
# memory usage: 923.1 KB

# %%
#audio_features.track_id = audio_features.track_id.asobject

# %%
audio_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13129 entries, 2 to 124911
# Data columns (total 8 columns):
# acousticness        13129 non-null float64
# danceability        13129 non-null float64
# energy              13129 non-null float64
# instrumentalness    13129 non-null float64
# liveness            13129 non-null float64
# speechiness         13129 non-null float64
# tempo               13129 non-null float64
# valence             13129 non-null float64
# dtypes: float64(8)
# memory usage: 923.1 KB

# %%
#audio_features.index = audio_features.track_id
audio_features.head()
# Out:
#           acousticness  danceability    energy  instrumentalness  liveness  \
# track_id
# 2             0.416675      0.675894  0.634476          0.010628  0.177647
# 3             0.374408      0.528643  0.817461          0.001851  0.105880
# 5             0.043567      0.745566  0.701470          0.000697  0.373143
# 10            0.951670      0.658179  0.924525          0.965427  0.115474
# 134           0.452217      0.513238  0.560410          0.019443  0.096567
#
#           speechiness    tempo   valence
# track_id
# 2            0.159310  165.922  0.576661
# 3            0.461818  126.957  0.269240
# 5            0.124595  100.260  0.621661
# 10           0.032985  111.562  0.963590
# 134          0.525519  114.290  0.894072

# %%
#https://stackoverflow.com/questions/40468069/python-pandas-merge-two-dataframes-by-index

# %%
pd.merge(tracks, audio_features, left_index=True, right_index=True)
# Out:
# Empty DataFrame
# Columns: [year_released, album, album_id, artist_id, artist, genres_top, genres_all, track, duration, acousticness, danceability, energy, instrumentalness, liveness, speechiness, tempo, valence]
# Index: []

# %%
audio_features.join(tracks).head()
# Out:
#           acousticness  danceability    energy  instrumentalness  liveness  \
# track_id
# 2             0.416675      0.675894  0.634476          0.010628  0.177647
# 3             0.374408      0.528643  0.817461          0.001851  0.105880
# 5             0.043567      0.745566  0.701470          0.000697  0.373143
# 10            0.951670      0.658179  0.924525          0.965427  0.115474
# 134           0.452217      0.513238  0.560410          0.019443  0.096567
#
#           speechiness    tempo   valence  year_released album album_id  \
# track_id
# 2            0.159310  165.922  0.576661            NaN   NaN      NaN
# 3            0.461818  126.957  0.269240            NaN   NaN      NaN
# 5            0.124595  100.260  0.621661            NaN   NaN      NaN
# 10           0.032985  111.562  0.963590            NaN   NaN      NaN
# 134          0.525519  114.290  0.894072            NaN   NaN      NaN
#
#          artist_id artist genres_top genres_all track  duration
# track_id
# 2              NaN    NaN        NaN        NaN   NaN       NaN
# 3              NaN    NaN        NaN        NaN   NaN       NaN
# 5              NaN    NaN        NaN        NaN   NaN       NaN
# 10             NaN    NaN        NaN        NaN   NaN       NaN
# 134            NaN    NaN        NaN        NaN   NaN       NaN

# %%
pd.concat([tracks, audio_features], axis=1)
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# <ipython-input-122-d3c4250e3be2> in <module>()
# ----> 1 pd.concat([tracks, audio_features], axis=1)
#
# C:\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, copy)
#     210                        keys=keys, levels=levels, names=names,
#     211                        verify_integrity=verify_integrity,
# --> 212                        copy=copy)
#     213     return op.get_result()
#     214
#
# C:\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy)
#     361         self.copy = copy
#     362
# --> 363         self.new_axes = self._get_new_axes()
#     364
#     365     def get_result(self):
#
# C:\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in _get_new_axes(self)
#     428                 if i == self.axis:
#     429                     continue
# --> 430                 new_axes[i] = self._get_comb_axis(i)
#     431         else:
#     432             if len(self.join_axes) != ndim - 1:
#
# C:\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in _get_comb_axis(self, i)
#     448         try:
#     449             return _get_objs_combined_axis(self.objs, axis=data_axis,
# --> 450                                            intersect=self.intersect)
#     451         except IndexError:
#     452             types = [type(x).__name__ for x in self.objs]
#
# C:\Anaconda3\lib\site-packages\pandas\core\indexes\api.py in _get_objs_combined_axis(objs, intersect, axis)
#      40                  if hasattr(obj, '_get_axis')]
#      41     if obs_idxes:
# ---> 42         return _get_combined_index(obs_idxes, intersect=intersect)
#      43
#      44
#
# C:\Anaconda3\lib\site-packages\pandas\core\indexes\api.py in _get_combined_index(indexes, intersect)
#      55             index = index.intersection(other)
#      56         return index
# ---> 57     union = _union_indexes(indexes)
#      58     return _ensure_index(union)
#      59
#
# C:\Anaconda3\lib\site-packages\pandas\core\indexes\api.py in _union_indexes(indexes)
#      85         else:
#      86             for other in indexes[1:]:
# ---> 87                 result = result.union(other)
#      88             return result
#      89     elif kind == 'array':
#
# C:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in union(self, other)
#    2224             this = self.astype('O')
#    2225             other = other.astype('O')
# -> 2226             return this.union(other)
#    2227
#    2228         if self.is_monotonic and other.is_monotonic:
#
# C:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in union(self, other)
#    2237                 result.extend([x for x in other._values if x not in value_set])
#    2238         else:
# -> 2239             indexer = self.get_indexer(other)
#    2240             indexer, = (indexer == -1).nonzero()
#    2241
#
# C:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_indexer(self, target, method, limit, tolerance)
#    2685
#    2686         if not self.is_unique:
# -> 2687             raise InvalidIndexError('Reindexing only valid with uniquely'
#    2688                                     ' valued Index objects')
#    2689
#
# InvalidIndexError: Reindexing only valid with uniquely valued Index objects
