# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
from datetime import datetime, timedelta

# %%
users = pd.read_csv("takehome_users_utf8.csv")
engagement = pd.read_csv("takehome_user_engagement_utf8.csv")

# %%
users.head()
# Out:
#    object_id    creation_time               name                       email  \
# 0          1   4/22/2014 3:53     Clausen August    AugustCClausen@yahoo.com
# 1          2  11/15/2013 3:45      Poole Matthew      MatthewPoole@gustr.com
# 2          3  3/19/2013 23:14  Bottrill Mitchell  MitchellBottrill@gustr.com
# 3          4   5/21/2013 8:09    Clausen Nicklas   NicklasSClausen@yahoo.com
# 4          5  1/17/2013 10:14          Raw Grace          GraceRaw@yahoo.com
#
#   creation_source  last_session_creation_time  opted_in_to_mailing_list  \
# 0    GUEST_INVITE                1.398139e+09                         1
# 1      ORG_INVITE                1.396238e+09                         0
# 2      ORG_INVITE                1.363735e+09                         0
# 3    GUEST_INVITE                1.369210e+09                         0
# 4    GUEST_INVITE                1.358850e+09                         0
#
#    enabled_for_marketing_drip  org_id  invited_by_user_id
# ...

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 10 columns):
# object_id                     12000 non-null int64
# creation_time                 12000 non-null object
# name                          12000 non-null object
# email                         12000 non-null object
# creation_source               12000 non-null object
# last_session_creation_time    8823 non-null float64
# opted_in_to_mailing_list      12000 non-null int64
# enabled_for_marketing_drip    12000 non-null int64
# org_id                        12000 non-null int64
# invited_by_user_id            6417 non-null float64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 937.6+ KB

# %%
users.creation_source.value_counts()
# Out:
# ORG_INVITE            4254
# GUEST_INVITE          2163
# PERSONAL_PROJECTS     2111
# SIGNUP                2087
# SIGNUP_GOOGLE_AUTH    1385
# Name: creation_source, dtype: int64

# %%
users.creation_source.hist()

# %%
engagement.head()
# Out:
#         time_stamp  user_id  visited
# 0   4/22/2014 3:53        1        1
# 1  11/15/2013 3:45        2        1
# 2  11/29/2013 3:45        2        1
# 3   12/9/2013 3:45        2        1
# 4  12/25/2013 3:45        2        1

# %%
engagement.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207917 entries, 0 to 207916
# Data columns (total 3 columns):
# time_stamp    207917 non-null object
# user_id       207917 non-null int64
# visited       207917 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 4.8+ MB

# %%
engagement.groupby('user_id').agg('max')
# Out:
#                time_stamp  visited
# user_id
# 1          4/22/2014 3:53        1
# 2           3/9/2014 3:45        1
# 3         3/19/2013 23:14        1
# 4          5/22/2013 8:09        1
# 5         1/22/2013 10:14        1
# 6         12/19/2013 3:37        1
# 7        12/20/2012 13:24        1
# 10         9/9/2013 22:08        1
# 11        12/27/2013 3:55        1
# 13        3/30/2014 16:19        1
# 14       10/12/2012 16:14        1
# 17        4/12/2014 14:39        1
# 19        5/30/2013 14:56        1
# 20         5/7/2014 11:46        1
# 21        1/22/2013 12:27        1
# 22         2/10/2014 6:00        1
# 23         8/18/2012 8:30        1
# 24         9/9/2013 22:20        1
# 25         2/26/2014 0:11        1
# 27        1/15/2014 17:35        1
# 28        2/14/2013 20:00        1
# 29         9/17/2013 2:08        1
# 30          6/4/2013 0:44        1
# 31         1/24/2014 5:21        1
# 33         5/31/2014 6:29        1
# ...

# %% [markdown]
# ### 1. Find The Adopted Users
# Define adopted users as the users who log into the prodcut on 3 separate days in one 7 day period.
#
# I first break the user engagement down to find users who logged on at least 3 times. Then, I integrate them back in the dataframe `users`.

# %%
user_visits = engagement.groupby('user_id').agg({'visited':'count'})
active_users = user_visits.loc[user_visits.visited >= 3].index.values
engagement = engagement.loc[engagement.user_id.isin(active_users)]
engagement.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 201002 entries, 1 to 207909
# Data columns (total 3 columns):
# time_stamp    201002 non-null object
# user_id       201002 non-null int64
# visited       201002 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 6.1+ MB

# %%
# Drop visited, a redundant column
engagement.drop(['visited'], axis=1, inplace=True)

# %%
engagement.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 201002 entries, 1 to 207909
# Data columns (total 2 columns):
# time_stamp    201002 non-null object
# user_id       201002 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 4.6+ MB

# %%
# Convert to datetime
engagement.time_stamp = pd.to_datetime(engagement.time_stamp).dt.normalize()
engagement.rename({'time_stamp':'date'}, axis=1, inplace=True)
engagement.head()
# Out:
#         date  user_id
# 1 2013-11-15        2
# 2 2013-11-29        2
# 3 2013-12-09        2
# 4 2013-12-25        2
# 5 2013-12-31        2

# %%
engagement['date'] = pd.to_timedelta(engagement.date)
engagement.rename({'date':'days'}, axis=1, inplace=True)
engagement.head()
# Out:
#         days  user_id
# 1 16024 days        2
# 2 16038 days        2
# 3 16048 days        2
# 4 16064 days        2
# 5 16070 days        2

# %%
# Create a groupby object based on user_id
engagement_gb = engagement.groupby('user_id')

# %%
# https://github.com/naveenrc/RelaxChallenge/blob/master/RelaxChallenge.ipynb

def find_adopted_users(x):
    """
    Takes property object x
    converts x to list
    returns 1 if a user logged into the product on three separate
    days in at least one seven day period 
    """
    user_history = [i for i in x]  # convert property object to list
    user_history.sort()  # sort the dates in increasing order
    user_history = [user_history[i+1] - user_history[i] for i in range(len(user_history)-2)]  # compute cumulative difference of current and next day
    # sum i, i+1, i+2 terms and check if it`s less than 7 which gives if it`s in a seven day period
    user_history = [1 for i in range(len(user_history)-2) if user_history[i] + user_history[i+1] + user_history[i+2] <= timedelta(days=7)]
    # condition to check if there`s a 1 in x, return 1 if true
    if 1 in user_history:
        return 1

df_adopted_users = engagement_gb.agg(find_adopted_users)  # group by user_id and aggregate using custom function
df_adopted_users.fillna(0, inplace=True)  # fill null values with 0
df_adopted_users.columns = ['adopted_user']
df_adopted_users.head()
# Out:
#          adopted_user
# user_id
# 2                 0.0
# 10                1.0
# 20                0.0
# 33                0.0
# 42                1.0

# %%
adopted_users = df_adopted_users.loc[df_adopted_users.adopted_user==1].index.values
users['adopted_user'] = users.object_id.apply(lambda x: 1 if x in adopted_users else 0)
users.head(10)
# Out:
#    object_id     creation_time               name  \
# 0          1    4/22/2014 3:53     Clausen August
# 1          2   11/15/2013 3:45      Poole Matthew
# 2          3   3/19/2013 23:14  Bottrill Mitchell
# 3          4    5/21/2013 8:09    Clausen Nicklas
# 4          5   1/17/2013 10:14          Raw Grace
# 5          6   12/17/2013 3:37      Cunha Eduardo
# 6          7  12/16/2012 13:24       Sewell Tyler
# 7          8    7/31/2013 5:34  Hamilton Danielle
# 8          9    11/5/2013 4:04         Amsel Paul
# 9         10   1/16/2013 22:08       Santos Carla
#
#                            email    creation_source  \
# 0       AugustCClausen@yahoo.com       GUEST_INVITE
# 1         MatthewPoole@gustr.com         ORG_INVITE
# 2     MitchellBottrill@gustr.com         ORG_INVITE
# 3      NicklasSClausen@yahoo.com       GUEST_INVITE
# 4             GraceRaw@yahoo.com       GUEST_INVITE
# 5  EduardoPereiraCunha@yahoo.com       GUEST_INVITE
# ...

# %%
engagement.groupby('user_id').agg('max')
# Out:
#               days
# user_id
# 2       16160 days
# 10      16224 days
# 20      16219 days
# 33      16221 days
# 42      16215 days
# 43      15810 days
# 50      15636 days
# 53      15830 days
# 59      16222 days
# 60      16205 days
# 63      16225 days
# 69      16220 days
# 74      15941 days
# 77      15722 days
# 80      16194 days
# 81      16218 days
# 82      16225 days
# 87      16212 days
# 95      16191 days
# 126     15972 days
# 133     16208 days
# 135     16223 days
# 136     16211 days
# 141     16104 days
# 142     16215 days
# 146     16225 days
# 153     16214 days
# 160     16214 days
# 165     15802 days
# 168     16220 days
# ...            ...
# 11873   16219 days
# 11879   16220 days
# 11880   16087 days
# 11885   16225 days
# 11893   16220 days
# 11895   16225 days
# 11902   16218 days
# 11904   15750 days
# 11906   16225 days
# 11909   16215 days
# 11913   16212 days
# 11920   16217 days
# 11924   16225 days
# 11935   15735 days
# 11939   16129 days
# ...

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 11 columns):
# object_id                     12000 non-null int64
# creation_time                 12000 non-null object
# name                          12000 non-null object
# email                         12000 non-null object
# creation_source               12000 non-null object
# last_session_creation_time    8823 non-null float64
# opted_in_to_mailing_list      12000 non-null int64
# enabled_for_marketing_drip    12000 non-null int64
# org_id                        12000 non-null int64
# invited_by_user_id            6417 non-null float64
# adopted_user                  12000 non-null int64
# dtypes: float64(2), int64(5), object(4)
# memory usage: 1.0+ MB

# %% [markdown]
# ### 2. Data Wrangling and Feature Engineering
# Now that the target variable (adopted_user) has been extracted, it's time to compile relevant features. Since this case study deals mostly with categorical data, I'll deal mostly with categorical features. Identifier information (name, email) doesn't have useful information, so those columns will be dropped. I will also introduce new features:
# - org_bin: org_id's are separated by bin in order of how frequent they appear based on quartiles.
# - users_invited: using information on the invited users, data about which users invited other users can be extracted. This column tracks how many users each user invited.

# %%
users.rename({'object_id': 'user_id'}, axis=1, inplace=True)
users.drop(['name', 'email'], axis=1, inplace=True)
users.head(10)
# Out:
#    user_id     creation_time    creation_source  last_session_creation_time  \
# 0        1    4/22/2014 3:53       GUEST_INVITE                1.398139e+09
# 1        2   11/15/2013 3:45         ORG_INVITE                1.396238e+09
# 2        3   3/19/2013 23:14         ORG_INVITE                1.363735e+09
# 3        4    5/21/2013 8:09       GUEST_INVITE                1.369210e+09
# 4        5   1/17/2013 10:14       GUEST_INVITE                1.358850e+09
# 5        6   12/17/2013 3:37       GUEST_INVITE                1.387424e+09
# 6        7  12/16/2012 13:24             SIGNUP                1.356010e+09
# 7        8    7/31/2013 5:34  PERSONAL_PROJECTS                         NaN
# 8        9    11/5/2013 4:04  PERSONAL_PROJECTS                         NaN
# 9       10   1/16/2013 22:08         ORG_INVITE                1.401833e+09
#
#    opted_in_to_mailing_list  enabled_for_marketing_drip  org_id  \
# 0                         1                           0      11
# ...

# %% [markdown]
# Bin organization ID's by frequency

# %%
users.drop(['last_session_creation_time'], axis=1, inplace=True)
users.head(10)
# Out:
#    user_id     creation_time    creation_source  opted_in_to_mailing_list  \
# 0        1    4/22/2014 3:53       GUEST_INVITE                         1
# 1        2   11/15/2013 3:45         ORG_INVITE                         0
# 2        3   3/19/2013 23:14         ORG_INVITE                         0
# 3        4    5/21/2013 8:09       GUEST_INVITE                         0
# 4        5   1/17/2013 10:14       GUEST_INVITE                         0
# 5        6   12/17/2013 3:37       GUEST_INVITE                         0
# 6        7  12/16/2012 13:24             SIGNUP                         0
# 7        8    7/31/2013 5:34  PERSONAL_PROJECTS                         1
# 8        9    11/5/2013 4:04  PERSONAL_PROJECTS                         0
# 9       10   1/16/2013 22:08         ORG_INVITE                         1
#
#    enabled_for_marketing_drip  org_id  invited_by_user_id  adopted_user
# 0                           0      11             10803.0             0
# ...

# %%
users['creation_time'] = pd.to_datetime(users.creation_time)

users['creation_time'] = pd.to_timedelta(users.creation_time)
#users.creation_time.min(), users.creation_time.max()

# %%
users.org_id.value_counts().hist()

# %%
org_frequencies = dict(users.org_id.value_counts())

# %%
lower_quartile, median, upper_quartile = users.org_id.value_counts().quantile([.25, .5, .75])
print(lower_quartile, median, upper_quartile)
users.org_id.value_counts().describe()
# Out:
# 17.0 22.0 29.0
# count    417.000000
# mean      28.776978
# std       27.560173
# min        2.000000
# 25%       17.000000
# 50%       22.000000
# 75%       29.000000
# max      319.000000
# Name: org_id, dtype: float64

# %%
org_id_value_counts = users.org_id.value_counts()

# %%
org_id_value_counts[:10]
# Out:
# 0     319
# 1     233
# 2     201
# 3     168
# 4     159
# 6     138
# 5     128
# 9     124
# 7     119
# 10    104
# Name: org_id, dtype: int64

# %%
def bin_by_quartile(x, lower, mid, upper):

    if x <= lower:
        return 1
    elif x <= mid:
        return 2
    elif x <= upper:
        return 3
    else:
        return 4
    
org_id_bin = dict(org_id_value_counts.apply(bin_by_quartile, args=(lower_quartile, median, upper_quartile)))

# %%
users['org_bin'] = users.org_id.map(lambda x:org_id_bin[x])
users.drop('org_id', axis=1, inplace=True)
users.head()
# Out:
#    user_id       creation_time creation_source  opted_in_to_mailing_list  \
# 0        1 16182 days 03:53:00    GUEST_INVITE                         1
# 1        2 16024 days 03:45:00      ORG_INVITE                         0
# 2        3 15783 days 23:14:00      ORG_INVITE                         0
# 3        4 15846 days 08:09:00    GUEST_INVITE                         0
# 4        5 15722 days 10:14:00    GUEST_INVITE                         0
#
#    enabled_for_marketing_drip  invited_by_user_id  adopted_user  org_bin
# 0                           0             10803.0             0        4
# 1                           0               316.0             0        4
# 2                           0              1525.0             0        4
# 3                           0              5151.0             0        4
# 4                           0              5240.0             0        1

# %%
users['org_bin'].hist()

# %%
users.invited_by_user_id.value_counts().describe()
# Out:
# count    2564.000000
# mean        2.502730
# std         1.900262
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max        13.000000
# Name: invited_by_user_id, dtype: float64

# %%
users.invited_by_user_id.value_counts().hist()

# %%
user_invite_vc = users.invited_by_user_id.value_counts()
user_invite_vc
# Out:
# 10741.0    13
# 2527.0     12
# 2308.0     11
# 1525.0     11
# 11770.0    11
# 10628.0    10
# 7012.0     10
# 4612.0     10
# 4803.0     10
# 1175.0     10
# 8068.0     10
# 4302.0     10
# 2354.0     10
# 6370.0     10
# 10481.0    10
# 9434.0      9
# 9023.0      9
# 2922.0      9
# 4551.0      9
# 6645.0      9
# 7698.0      9
# 3789.0      9
# 3721.0      9
# 8554.0      9
# 3944.0      9
# 7716.0      9
# 6808.0      9
# 6493.0      9
# 8426.0      9
# 264.0       8
#            ..
# 4885.0      1
# 5563.0      1
# 4231.0      1
# 3418.0      1
# 7837.0      1
# 3814.0      1
# 4655.0      1
# 10417.0     1
# 7979.0      1
# 5638.0      1
# 3422.0      1
# 6164.0      1
# 594.0       1
# 1750.0      1
# 6238.0      1
# 7425.0      1
# 5200.0      1
# 9325.0      1
# 4467.0      1
# 10335.0     1
# 7916.0      1
# 1945.0      1
# 11536.0     1
# 5989.0      1
# 11196.0     1
# 2746.0      1
# 10456.0     1
# 8371.0      1
# 6266.0      1
# 3572.0      1
# ...

# %%
## Add a feature that describes whether or not a user was invited by another user
users['invited_by_user'] = users.invited_by_user_id.apply(lambda x: 0 if np.isnan(x) else 1)

# %%
users.head()
# Out:
#    user_id       creation_time creation_source  opted_in_to_mailing_list  \
# 0        1 16182 days 03:53:00    GUEST_INVITE                         1
# 1        2 16024 days 03:45:00      ORG_INVITE                         0
# 2        3 15783 days 23:14:00      ORG_INVITE                         0
# 3        4 15846 days 08:09:00    GUEST_INVITE                         0
# 4        5 15722 days 10:14:00    GUEST_INVITE                         0
#
#    enabled_for_marketing_drip  invited_by_user_id  adopted_user  org_bin  \
# 0                           0             10803.0             0        4
# 1                           0               316.0             0        4
# 2                           0              1525.0             0        4
# 3                           0              5151.0             0        4
# 4                           0              5240.0             0        1
#
#    invited_by_user
# 0                1
# 1                1
# 2                1
# ...

# %%
users.loc[users.user_id.isin(user_invite_vc.index.values)]
# Out:
#        user_id       creation_time     creation_source  \
# 2            3 15783 days 23:14:00          ORG_INVITE
# 6            7 15690 days 13:24:00              SIGNUP
# 9           10 15721 days 22:08:00          ORG_INVITE
# 20          21 15727 days 12:27:00   PERSONAL_PROJECTS
# 22          23 15569 days 08:30:00          ORG_INVITE
# 28          29 15964 days 02:08:00              SIGNUP
# 36          37 15608 days 14:37:00              SIGNUP
# 46          47 15498 days 13:23:00          ORG_INVITE
# 48          49 15991 days 10:06:00              SIGNUP
# 49          50 15494 days 11:02:00        GUEST_INVITE
# 54          55 15539 days 23:00:00  SIGNUP_GOOGLE_AUTH
# 68          69 15520 days 10:15:00        GUEST_INVITE
# 77          78 15519 days 17:36:00   PERSONAL_PROJECTS
# 78          79 15854 days 20:17:00        GUEST_INVITE
# 92          93 15593 days 08:07:00          ORG_INVITE
# 102        103 15676 days 10:44:00        GUEST_INVITE
# ...

# %%
# Add a feature on whether a user successfully invited another
#user_inviters = users.invited_by_user_id.unique()
#users['invited_user'] = users.user_id.isin(user_inviters)
#users['invited_user'] = users.invited_user.astype(int)
users['users_invited'] = users.loc[users.user_id.isin(user_invite_vc.index.values), 'user_id'].apply(lambda x:user_invite_vc[x])
users['users_invited'] = users['users_invited'].fillna(0)
users.drop(['invited_by_user_id'], axis=1, inplace=True)
users.head()
# Out:
#    user_id       creation_time creation_source  opted_in_to_mailing_list  \
# 0        1 16182 days 03:53:00    GUEST_INVITE                         1
# 1        2 16024 days 03:45:00      ORG_INVITE                         0
# 2        3 15783 days 23:14:00      ORG_INVITE                         0
# 3        4 15846 days 08:09:00    GUEST_INVITE                         0
# 4        5 15722 days 10:14:00    GUEST_INVITE                         0
#
#    enabled_for_marketing_drip  adopted_user  org_bin  invited_by_user  \
# 0                           0             0        4                1
# 1                           0             0        4                1
# 2                           0             0        4                1
# 3                           0             0        4                1
# 4                           0             0        1                1
#
#    users_invited
# 0            0.0
# 1            0.0
# 2            1.0
# 3            0.0
# ...

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 9 columns):
# user_id                       12000 non-null int64
# creation_time                 12000 non-null timedelta64[ns]
# creation_source               12000 non-null object
# opted_in_to_mailing_list      12000 non-null int64
# enabled_for_marketing_drip    12000 non-null int64
# adopted_user                  12000 non-null int64
# org_bin                       12000 non-null int64
# invited_by_user               12000 non-null int64
# users_invited                 12000 non-null float64
# dtypes: float64(1), int64(6), object(1), timedelta64[ns](1)
# memory usage: 843.8+ KB

# %%
cat_cols = ['opted_in_to_mailing_list', 'enabled_for_marketing_drip', 'org_bin', 'invited_by_user', 'users_invited']
users[cat_cols].hist(figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001DDE5100048>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001DDE51B1940>]], dtype=object)

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, Binarizer, LabelBinarizer

# %%
print("adopted users: ", sum(users.adopted_user))
print("total users: ", len(users))
# Out:
# adopted users:  1322
# total users:  12000

# %% [markdown]
# ### 3. Training and Testing with a decision tree classifier

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score, f1_score, precision_score, confusion_matrix, recall_score

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 9 columns):
# user_id                       12000 non-null int64
# creation_time                 12000 non-null timedelta64[ns]
# creation_source               12000 non-null object
# opted_in_to_mailing_list      12000 non-null int64
# enabled_for_marketing_drip    12000 non-null int64
# adopted_user                  12000 non-null int64
# org_bin                       12000 non-null int64
# invited_by_user               12000 non-null int64
# users_invited                 12000 non-null float64
# dtypes: float64(1), int64(6), object(1), timedelta64[ns](1)
# memory usage: 843.8+ KB

# %%
users.head(10)
# Out:
#    user_id       creation_time    creation_source  opted_in_to_mailing_list  \
# 0        1 16182 days 03:53:00       GUEST_INVITE                         1
# 1        2 16024 days 03:45:00         ORG_INVITE                         0
# 2        3 15783 days 23:14:00         ORG_INVITE                         0
# 3        4 15846 days 08:09:00       GUEST_INVITE                         0
# 4        5 15722 days 10:14:00       GUEST_INVITE                         0
# 5        6 16056 days 03:37:00       GUEST_INVITE                         0
# 6        7 15690 days 13:24:00             SIGNUP                         0
# 7        8 15917 days 05:34:00  PERSONAL_PROJECTS                         1
# 8        9 16014 days 04:04:00  PERSONAL_PROJECTS                         0
# 9       10 15721 days 22:08:00         ORG_INVITE                         1
#
#    enabled_for_marketing_drip  adopted_user  org_bin  invited_by_user  \
# ...

# %%
# le = LabelEncoder()
# le.fit(users.creation_source)
# creation_source_enc = le.transform(users.creation_source)
# users.creation_source = creation_source_enc
# # users.creation_source = users.creation_source.astype('category')
# users.head(10)

# %%
users.set_index('user_id', inplace=True)

# %%
#users = pd.get_dummies(users_copy)
users
# Out:
#               creation_time     creation_source  opted_in_to_mailing_list  \
# user_id
# 1       16182 days 03:53:00        GUEST_INVITE                         1
# 2       16024 days 03:45:00          ORG_INVITE                         0
# 3       15783 days 23:14:00          ORG_INVITE                         0
# 4       15846 days 08:09:00        GUEST_INVITE                         0
# 5       15722 days 10:14:00        GUEST_INVITE                         0
# 6       16056 days 03:37:00        GUEST_INVITE                         0
# 7       15690 days 13:24:00              SIGNUP                         0
# 8       15917 days 05:34:00   PERSONAL_PROJECTS                         1
# 9       16014 days 04:04:00   PERSONAL_PROJECTS                         0
# 10      15721 days 22:08:00          ORG_INVITE                         1
# 11      16065 days 03:55:00              SIGNUP                         0
# ...

# %%
feature_cols = ['creation_source','opted_in_to_mailing_list', 'enabled_for_marketing_drip', 'org_bin', 'invited_by_user', 'users_invited']
target_col = ['adopted_user']
cols = feature_cols + target_col
users[cols]
# Out:
#             creation_source  opted_in_to_mailing_list  \
# user_id
# 1              GUEST_INVITE                         1
# 2                ORG_INVITE                         0
# 3                ORG_INVITE                         0
# 4              GUEST_INVITE                         0
# 5              GUEST_INVITE                         0
# 6              GUEST_INVITE                         0
# 7                    SIGNUP                         0
# 8         PERSONAL_PROJECTS                         1
# 9         PERSONAL_PROJECTS                         0
# 10               ORG_INVITE                         1
# 11                   SIGNUP                         0
# 12               ORG_INVITE                         0
# 13               ORG_INVITE                         0
# 14                   SIGNUP                         0
# 15        PERSONAL_PROJECTS                         0
# 16        PERSONAL_PROJECTS                         0
# ...

# %%
le = LabelEncoder()

users['creation_source'] = le.fit_transform(users['creation_source'])
users.head()
# Out:
#               creation_time  creation_source  opted_in_to_mailing_list  \
# user_id
# 1       16182 days 03:53:00                0                         1
# 2       16024 days 03:45:00                1                         0
# 3       15783 days 23:14:00                1                         0
# 4       15846 days 08:09:00                0                         0
# 5       15722 days 10:14:00                0                         0
#
#          enabled_for_marketing_drip  adopted_user  org_bin  invited_by_user  \
# user_id
# 1                                 0             0        4                1
# 2                                 0             0        4                1
# 3                                 0             0        4                1
# 4                                 0             0        4                1
# 5                                 0             0        1                1
#
#          users_invited
# user_id
# 1                  0.0
# ...

# %%
enc = OneHotEncoder()

enc.fit_transform(users[cat_cols])
# Out:
# <12000x24 sparse matrix of type '<class 'numpy.float64'>'
# 	with 60000 stored elements in Compressed Sparse Row format>

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12000 entries, 1 to 12000
# Data columns (total 8 columns):
# creation_time                 12000 non-null timedelta64[ns]
# creation_source               12000 non-null int64
# opted_in_to_mailing_list      12000 non-null int64
# enabled_for_marketing_drip    12000 non-null int64
# adopted_user                  12000 non-null int64
# org_bin                       12000 non-null int64
# invited_by_user               12000 non-null int64
# users_invited                 12000 non-null float64
# dtypes: float64(1), int64(6), timedelta64[ns](1)
# memory usage: 843.8 KB

# %%
feature_cols = ['creation_source','opted_in_to_mailing_list', 'enabled_for_marketing_drip', 'org_bin', 'invited_by_user', 'users_invited']
target_col = ['adopted_user']
cols = feature_cols + target_col
users_copy = users[cols].copy()
cat_cols = ['creation_source','opted_in_to_mailing_list', 'enabled_for_marketing_drip', 'org_bin', 'invited_by_user']
num_cols = ['users_invited']

users_copy = users[cols].copy()

# for col in cat_cols:
#     users_copy[col] = users_copy[col].astype('category')


users_copy.info()
#enc.fit_transform(users_copy[cat_cols])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12000 entries, 1 to 12000
# Data columns (total 7 columns):
# creation_source               12000 non-null int64
# opted_in_to_mailing_list      12000 non-null int64
# enabled_for_marketing_drip    12000 non-null int64
# org_bin                       12000 non-null int64
# invited_by_user               12000 non-null int64
# users_invited                 12000 non-null float64
# adopted_user                  12000 non-null int64
# dtypes: float64(1), int64(6)
# memory usage: 750.0 KB

# %%
X = users_copy[users_copy.columns.difference(['adopted_user'])]
y = users_copy.adopted_user.values
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42618, stratify=y, test_size=0.3)

# %%
dtc = DecisionTreeClassifier()
dtc.fit(X_train, y_train)
y_pred = dtc.predict(X_test)
y_prob = dtc.predict_proba(X_test)

adopt_pct = sum(users.adopted_user)/len(users)

n = len(y_prob)
probs = list(zip(*y_prob))
probs_1 = [y for x in probs for y in x][n:]
#non_adopt_pct = 1-adopt_pct
preds = [1 if (pct > adopt_pct) else 0 for pct in probs_1]

# classification_report(y_test, y_pred)
metrics = {'accuracy':accuracy_score, 
           'precision':precision_score,
           'recall':recall_score,
           'f1':f1_score, 
          }
for metric_name, metric in metrics.items():
    print("{}: {}".format(metric_name, metric(y_test, preds)))
# Out:
# f1: 0.2012667135819845
# precision: 0.1396484375
# accuracy: 0.6847222222222222
# recall: 0.3602015113350126

# %%
adopt_pct
# Out:
# 0.11016666666666666

# %%
# feature_cols = ['creation_source','opted_in_to_mailing_list', 'enabled_for_marketing_drip', 'org_bin', 'invited_by_user', 'users_invited']

# target_col = ['adopted_user']
# cols = feature_cols + target_col
# users_copy = users[cols].copy()
# cat_cols = ['creation_source','opted_in_to_mailing_list', 'enabled_for_marketing_drip', 'org_bin', 'invited_by_user']
# num_cols = ['users_invited']
# # users_copy.opted_in_to_mailing_list = users.opted_in_to_mailing_list.astype('category')
# # users_copy.enabled_for_marketing_drip = users.enabled_for_marketing_drip.astype('category')
# # users_copy.invited_by_user_id = users.invited_by_user_id.astype('category')
# # users_copy.creation_source = users.creation_source.astype('category')
# # users_copy.adopted_user = users.adopted_user.astype('category')
# users_copy = pd.get_dummies(users_copy)

# enc = OneHotEncoder()
# le = LabelEncoder()
# X = users_copy[users_copy.columns.difference(['adopted_user'])]
# y = users_copy.adopted_user.values

# bi = LabelBinarizer()
# enc.fit(X)
# X = enc.transform(X).toarray()
# #y = ohe.fit_transform(y.reshape(-1,1))
# y = le.fit_transform(y.reshape(-1,1))
# X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42618, stratify=y, test_size=0.3)

# dtc = DecisionTreeClassifier()
# dtc.fit(X_train, y_train)
# y_pred = dtc.predict(X_test)
# y_prob = dtc.predict_proba(X_test)

# adopt_pct = sum(users.adopted_user)/len(users)

# n = len(y_prob)
# probs = list(zip(*y_prob))
# probs_1 = [y for x in probs for y in x][n:]
# #non_adopt_pct = 1-adopt_pct
# preds = [1 if (pct > adopt_pct) else 0 for pct in probs_1]

# # classification_report(y_test, y_pred)
# metrics = {'accuracy':accuracy_score, 
#            'precision':precision_score,
#            'recall':recall_score,
#            'f1':f1_score, 
#           }
# for metric_name, metric in metrics.items():
#     print("{}: {}".format(metric_name, metric(y_test, preds)))

# %%
from pandas_ml import ConfusionMatrix
cm = ConfusionMatrix(y_test, preds)
cm.print_stats()
# Out:
# population: 3600
# P: 397
# N: 3203
# PositiveTest: 1024
# NegativeTest: 2576
# TP: 143
# TN: 2322
# FP: 881
# FN: 254
# TPR: 0.360201511335
# TNR: 0.724945363722
# PPV: 0.1396484375
# NPV: 0.901397515528
# FPR: 0.275054636278
# FDR: 0.8603515625
# FNR: 0.639798488665
# ACC: 0.684722222222
# F1_score: 0.201266713582
# MCC: 0.0591179721747
# informedness: 0.0851468750565
# markedness: 0.041045953028
# prevalence: 0.110277777778
# LRP: 1.30956349694
# LRN: 0.882547183115
# DOR: 1.48384530821
# FOR: 0.098602484472

# %%
cm.plot()

# %%
dict(zip(feature_cols,dtc.feature_importances_))
# Out:
# {'creation_source': 0.13695122457806169,
#  'enabled_for_marketing_drip': 0.024385655913292795,
#  'invited_by_user': 0.20823043749500356,
#  'opted_in_to_mailing_list': 0.089070135103893652,
#  'org_bin': 0.12422547573009385,
#  'users_invited': 0.41713707117965443}

# %%
from sklearn.linear_model import LogisticRegression
adopt_pct = sum(users.adopted_user)/len(users)

lr = LogisticRegression(
#    class_weight={1:adopt_pct, 0:1-adopt_pct}
)
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)
y_prob = lr.predict_proba(X_test)


n = len(y_prob)
probs = list(zip(*y_prob))
probs_1 = [y for x in probs for y in x][n:]
#non_adopt_pct = 1-adopt_pct
preds = [1 if (pct > adopt_pct) else 0 for pct in probs_1]
#preds = y_pred

# classification_report(y_test, y_pred)
metrics = {'accuracy':accuracy_score, 
           'precision':precision_score,
           'recall':recall_score,
           'f1':f1_score, 
          }
for metric_name, metric in metrics.items():
    print("{}: {}".format(metric_name, metric(y_test, preds)))
# Out:
# f1: 0.2141019042717447
# precision: 0.13454075032341525
# accuracy: 0.5758333333333333
# recall: 0.5239294710327456

# %%
cm = ConfusionMatrix(y_test, preds)
cm.print_stats()
# Out:
# population: 3600
# P: 397
# N: 3203
# PositiveTest: 1546
# NegativeTest: 2054
# TP: 208
# TN: 1865
# FP: 1338
# FN: 189
# TPR: 0.523929471033
# TNR: 0.582266625039
# PPV: 0.134540750323
# NPV: 0.907984420643
# FPR: 0.417733374961
# FDR: 0.865459249677
# FNR: 0.476070528967
# ACC: 0.575833333333
# F1_score: 0.214101904272
# MCC: 0.0672012436
# informedness: 0.106196096072
# markedness: 0.0425251709661
# prevalence: 0.110277777778
# LRP: 1.25421980248
# LRN: 0.817616034468
# DOR: 1.53399609304
# FOR: 0.0920155793574

# %%
cm.plot()

# %% [markdown]
# ### Results
# For a quick and dirty model, we got high recall, average accuracy and low precision and f1 scores. In a business sense, we want to minimize false negatives, because those false negatives incorrectly identify potential adopters as non-adopters. Thus having many false negatives turns away potental customers. On the flipside, incorrectly identifying false positives / adopted users is relatively inconsequential because they likely won't affect the adoption rate either way. So, recall is the most important metric and precision and accuracy aren't all that important.
# I also found that the marketing emails were the most important feature by far. More focus on this area may lead to higher adoption rates.
